# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

X_cols = [
    'compactness_ext', 
    #'compactness_int', 
    #'compactness_total', 
    'dist_centroid', 
    'angle_centroid', 
    'sin_centroid', 
    'cos_centroid', 
    'aspect_ratio', 
    'eccentricity', 
    'sin_major', 
    'cos_major', 
    'hog_0_30', 
    'hog_30_60', 
    'hog_60_90', 
    'hog_90_120', 
    'hog_120_150', 
    'hog_150_180', 
    'hog_180_210', 
    'hog_210_240', 
    'hog_240_270', 
    'hog_270_300', 
    'hog_300_330', 
    'hog_330_360', 
    'hu_1', 
    'hu_2', 
    'hu_3', 
    'hu_4', 
    'hu_5', 
    'hu_6', 
    'hu_7'
]

y_cols = ['qw', 'qx', 'qy', 'qz']

# %%
original_df = pd.read_excel('../../../processed/splitted_train_70_30.xlsx')
original_df
# Out:
#        object_id object_name  frame_id image_file_name       yaw_rad  \
# 0              1         ape         0      000000.png  0.000000e+00
# 1              1         ape         1      000001.png  2.125635e+00
# 2              1         ape         2      000002.png  3.141593e+00
# 3              1         ape         3      000003.png -2.125635e+00
# 4              1         ape         4      000004.png -1.015958e+00
# ...          ...         ...       ...             ...           ...
# 19690         15       phone      1308      001308.png  0.000000e+00
# 19691         15       phone      1309      001309.png  0.000000e+00
# 19692         15       phone      1310      001310.png -3.059233e-17
# 19693         15       phone      1311      001311.png  0.000000e+00
# 19694         15       phone      1312      001312.png  0.000000e+00
#
#        pitch_rad  roll_rad       yaw_deg  pitch_deg    roll_deg  ...  \
# 0       0.000000  3.141593  0.000000e+00   0.000000  180.000000  ...
# 1       0.063891 -3.102041  1.217899e+02   3.660707 -177.733884  ...
# 2       0.000000 -3.064492  1.800000e+02   0.000000 -175.582432  ...
# 3      -0.063891 -3.102041 -1.217899e+02  -3.660707 -177.733884  ...
# 4      -0.063891  3.102041 -5.821010e+01  -3.660707  177.733884  ...
# ...          ...       ...           ...        ...         ...  ...
# 19690   0.299709  1.570796  0.000000e+00  17.172038   90.000000  ...
# 19691   0.368616  1.570796  0.000000e+00  21.120113   90.000000  ...
# 19692   0.434045  1.570796 -1.752812e-15  24.868925   90.000000  ...
# 19693   0.495737  1.570796  0.000000e+00  28.403624   90.000000  ...
# 19694   0.553574  1.570796  0.000000e+00  31.717474   90.000000  ...
#
#        hog_300_330  hog_330_360      hu_1      hu_2      hu_3      hu_4  hu_5  \
# 0         0.187317     0.140488  2.659124  6.842549  8.794690  9.792664  10.0
# 1         0.163420     0.272367  2.654877  6.858704  8.856150  9.760574  10.0
# 2         0.160817     0.107211  2.664540  6.900149  8.871267  9.851155  10.0
# 3         0.247537     0.148522  2.668981  6.923616  8.834159  9.883283  10.0
# 4         0.456318     0.202808  2.666043  6.950905  8.817960  9.844575  10.0
# ...            ...          ...       ...       ...       ...       ...   ...
# 19690     0.189884     0.217010  2.548376  5.391186  7.959847  8.428499  10.0
# 19691     0.138198     0.193477  2.588207  5.490451  8.067648  8.537625  10.0
# 19692     0.112464     0.281161  2.621382  5.578462  8.157535  8.633517  10.0
# 19693     0.153293     0.255488  2.648526  5.655276  8.231664  8.717287  10.0
# 19694     0.055880     0.279399  2.670895  5.723586  8.292130  8.790467  10.0
#
#            hu_6  hu_7    set
# 0      9.999976  10.0  train
# 1      9.999984  10.0   test
# 2     -9.999993  10.0  train
# 3      9.999991  10.0  train
# 4      9.999974  10.0   test
# ...         ...   ...    ...
# 19690  9.969556  10.0   test
# 19691  9.978913  10.0  train
# 19692  9.984856  10.0  train
# 19693  9.988732  10.0  train
# 19694  9.991365 -10.0  train
#
# [19695 rows x 54 columns]

# %%
corr_matrix = original_df[X_cols+y_cols].corr()

plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
from sklearn.decomposition import PCA

pca_df = original_df.copy(deep=True)
pca = PCA()
pca_df[X_cols] = pd.DataFrame(pca.fit_transform(original_df[X_cols]), columns=X_cols)

# %%
explained     = pca.explained_variance_ratio_
explained_cum = np.cumsum(explained)
pc_labels     = [f'PC{i+1}' for i in range(len(X_cols))]

print('Variância explicada por componente:')
for label, var, cum in zip(pc_labels, explained, explained_cum):
    print(f'  {label}: {var*100:.2f}%  (acumulado: {cum*100:.2f}%)')

fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.bar(pc_labels, explained * 100, color='steelblue', edgecolor='white', label='Variância explicada')
ax1.set_xlabel('Componente Principal')
ax1.set_ylabel('Variância explicada (%)', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')
ax1.set_ylim(0, 110)

ax2 = ax1.twinx()
ax2.plot(pc_labels, explained_cum * 100, color='red', marker='o', linewidth=2, label='Variância acumulada')
ax2.axhline(90, color='gray', linestyle='--', linewidth=1, label='90%')
ax2.set_ylabel('Variância acumulada (%)', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 110)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right')

plt.title('PCA — Características de Entrada')
plt.tight_layout()
plt.savefig('../../../results/neural_networks/pca_components.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Variância explicada por componente:
#   PC1: 96.90%  (acumulado: 96.90%)
#   PC2: 1.37%  (acumulado: 98.27%)
#   PC3: 0.94%  (acumulado: 99.21%)
#   PC4: 0.41%  (acumulado: 99.62%)
#   PC5: 0.35%  (acumulado: 99.97%)
#   PC6: 0.01%  (acumulado: 99.98%)
#   PC7: 0.01%  (acumulado: 99.99%)
#   PC8: 0.01%  (acumulado: 99.99%)
#   PC9: 0.00%  (acumulado: 99.99%)
#   PC10: 0.00%  (acumulado: 100.00%)
#   PC11: 0.00%  (acumulado: 100.00%)
#   PC12: 0.00%  (acumulado: 100.00%)
#   PC13: 0.00%  (acumulado: 100.00%)
#   PC14: 0.00%  (acumulado: 100.00%)
#   PC15: 0.00%  (acumulado: 100.00%)
#   PC16: 0.00%  (acumulado: 100.00%)
#   PC17: 0.00%  (acumulado: 100.00%)
#   PC18: 0.00%  (acumulado: 100.00%)
#   PC19: 0.00%  (acumulado: 100.00%)
#   PC20: 0.00%  (acumulado: 100.00%)
#   PC21: 0.00%  (acumulado: 100.00%)
#   PC22: 0.00%  (acumulado: 100.00%)
#   PC23: 0.00%  (acumulado: 100.00%)
#   PC24: 0.00%  (acumulado: 100.00%)
#   PC25: 0.00%  (acumulado: 100.00%)
#   PC26: 0.00%  (acumulado: 100.00%)
#   PC27: 0.00%  (acumulado: 100.00%)
#   PC28: 0.00%  (acumulado: 100.00%)
